# %%
import pandas as pd
btc_path="../requirements/btc.csv"
btc_df=pd.read_csv(btc_path)

# %%
btc_df.columns
# Out:
# Index(['date', 'AdrActCnt', 'BlkCnt', 'BlkSizeByte', 'BlkSizeMeanByte',
#        'CapMVRVCur', 'CapMrktCurUSD', 'CapRealUSD', 'DiffMean', 'FeeMeanNtv',
#        'FeeMeanUSD', 'FeeMedNtv', 'FeeMedUSD', 'FeeTotNtv', 'FeeTotUSD',
#        'HashRate', 'IssContNtv', 'IssContPctAnn', 'IssContUSD', 'IssTotNtv',
#        'IssTotUSD', 'NVTAdj', 'NVTAdj90', 'PriceBTC', 'PriceUSD', 'ROI1yr',
#        'ROI30d', 'SplyCur', 'TxCnt', 'TxTfrCnt', 'TxTfrValAdjNtv',
#        'TxTfrValAdjUSD', 'TxTfrValMeanNtv', 'TxTfrValMeanUSD',
#        'TxTfrValMedNtv', 'TxTfrValMedUSD', 'TxTfrValNtv', 'TxTfrValUSD',
#        'VtyDayRet180d', 'VtyDayRet30d', 'VtyDayRet60d'],
#       dtype='object')

# %%
data_dict = btc_df.to_dict(orient='records')
dict_list=[]
for index, row in btc_df.iterrows():
    data_dict = row.to_dict()
    dict_list.append(data_dict)
# for entry in dict_list:
#        print(f"Date: {entry['date']}, PriceUSD: {entry['PriceUSD']}, TxTfrCnt: {entry['TxCnt']}")

# %%
dict_list
# Out:
# [{'date': '2009-01-03',
#   'AdrActCnt': 0.0,
#   'BlkCnt': 0.0,
#   'BlkSizeByte': 0.0,
#   'BlkSizeMeanByte': nan,
#   'CapMVRVCur': nan,
#   'CapMrktCurUSD': nan,
#   'CapRealUSD': 0.0,
#   'DiffMean': nan,
#   'FeeMeanNtv': nan,
#   'FeeMeanUSD': nan,
#   'FeeMedNtv': nan,
#   'FeeMedUSD': nan,
#   'FeeTotNtv': 0.0,
#   'FeeTotUSD': nan,
#   'HashRate': nan,
#   'IssContNtv': nan,
#   'IssContPctAnn': nan,
#   'IssContUSD': nan,
#   'IssTotNtv': nan,
#   'IssTotUSD': nan,
#   'NVTAdj': nan,
#   'NVTAdj90': nan,
#   'PriceBTC': 1,
#   'PriceUSD': nan,
#   'ROI1yr': nan,
#   'ROI30d': nan,
#   'SplyCur': 0.0,
#   'TxCnt': 0.0,
#   'TxTfrCnt': 0.0,
#   'TxTfrValAdjNtv': 0.0,
#   'TxTfrValAdjUSD': nan,
#   'TxTfrValMeanNtv': nan,
#   'TxTfrValMeanUSD': nan,
#   'TxTfrValMedNtv': nan,
#   'TxTfrValMedUSD': nan,
#   'TxTfrValNtv': 0.0,
#   'TxTfrValUSD': nan,
#   'VtyDayRet180d': nan,
#   'VtyDayRet30d': nan,
#   'VtyDayRet60d': nan},
#  {'date': '2009-01-04',
#   'AdrActCnt': 0.0,
# ...
